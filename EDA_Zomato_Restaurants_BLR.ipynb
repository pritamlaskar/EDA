# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/Pritam Laskar/Documents/EDA/Zomato Bangalore Restaurants/zomato.csv")

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                             phone  \
# 0            Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# 1             No   4.1/5    787                      080 41714161
# 2             No   3.8/5    918                    +91 9663487993
# 3             No   3.7/5     88                    +91 9620009302
# 4             No   3.8/5    166  +91 8026612447\r\n+91 9901210005
# ...          ...     ...    ...                               ...
# 51712         No  3.6 /5     27                      080 40301477
# 51713         No     NaN      0                    +91 8197675843
# 51714         No     NaN      0                               NaN
# 51715        Yes  4.3 /5    236                      080 49652769
# 51716         No  3.4 /5     13                    +91 8071117272
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 51712                  Whitefield                  Bar
# 51713                  Whitefield                  Bar
# 51714                  Whitefield                  Bar
# 51715  ITPL Main Road, Whitefield                  Bar
# 51716  ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                NaN
# 51713                                                NaN
# 51714                                                NaN
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                NaN
#
#                                      cuisines approx_cost(for two people)  \
# 0              North Indian, Mughlai, Chinese                         800
# 1                 Chinese, North Indian, Thai                         800
# 2                      Cafe, Mexican, Italian                         800
# 3                  South Indian, North Indian                         300
# 4                    North Indian, Rajasthani                         600
# ...                                       ...                         ...
# 51712                             Continental                       1,500
# 51713                             Finger Food                         600
# 51714                             Finger Food                       2,000
# 51715                             Finger Food                       2,500
# 51716  Finger Food, North Indian, Continental                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51713                                                 []        []
# 51714                                                 []        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51712   Pubs and bars      Whitefield
# 51713   Pubs and bars      Whitefield
# 51714   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [51717 rows x 17 columns]

# %%
# Check null values:

df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
# Check the percentage of null values in each column: 

(df.isnull().sum()/len(df))*100
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           15.033741
# votes                           0.000000
# phone                           2.335789
# location                        0.040606
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# dtype: float64

# %%
# Check duplicates:
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
# Remove duplicates:

df.drop_duplicates(inplace = True)

# %%
# Check shape after removing duplicates:

df.shape

# No duplicates found as shape is same before and after remove_duplicate function
# Out:
# (51717, 17)

# %%
# Check data types of columns:

df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
# # Data Cleaning # #

# %%
# Cleaning in 'rate' columns:

# %%
# Check unique values in 'rate':
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
# Import numpy:

import numpy as np

# %%
# Replace 'NEW' and '-' with nan by calling np:

df['rate'].replace(['NEW', '-'], np.nan, inplace = True)

# %%
# Check percentage of null values after making changes in 'rate' column above:

(df.isnull().sum()/len(df))*100
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           19.436549
# votes                           0.000000
# phone                           2.335789
# location                        0.040606
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# dtype: float64

# %%
# Now check unique after making changes in 'rate' column:

df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', nan, '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
# Remove '/5' from rate by creating two different columns using split:

df[['new rate 1', 'new rate 2']] = df['rate'].str.split('/', expand = True)

# %%
# Check the new columns:

df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city) new rate 1 new rate 2
# 0          Buffet    Banashankari        4.1          5
# 1          Buffet    Banashankari        4.1          5
# 2          Buffet    Banashankari        3.8          5
# 3          Buffet    Banashankari        3.7          5
# 4          Buffet    Banashankari        3.8          5

# %%
# Drop 'new rate 2' column:

df.drop('new rate 2', axis = 1, inplace = True)

# %%
# Rename 'new rate 1' to 'rate1':

df = df.rename(columns = {'new rate 1':'rate1'})

# %%
# Change dtype of 'rate1' from object to float:

df['rate1'] = df['rate1'].astype('float')

# %%
# Check dtype of 'rate1': 

df['rate1'].dtype
# Out:
# dtype('float64')

# %%
# Replace null values of 'rate1' with mean of 'rate1'

df['rate1'] = df['rate1'].fillna(df['rate1'].mean())

# %%
(df.isnull().sum()/len(df))*100
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           19.436549
# votes                           0.000000
# phone                           2.335789
# location                        0.040606
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# rate1                           0.000000
# dtype: float64

# %%
# Check mode of 'rest_type':

df['rest_type'].mode()
# Out:
# 0    Quick Bites
# Name: rest_type, dtype: object

# %%
# Fill null values of 'rest_type' with mode of 'rest_type':

df['rest_type'] = df['rest_type'].fillna(df['rest_type'].mode())

# %%
# Find mode of approx cost of two people:

df['approx_cost(for two people)'].mode()
# Out:
# 0    300
# Name: approx_cost(for two people), dtype: object

# %%
# Fill null values of approx cost column with mode:

df['approx_cost(for two people)'] = df['approx_cost(for two people)'].fillna(df['approx_cost(for two people)'].mode())

# %%
# Find unique values in 'approx cost for two people':

df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', nan, '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %%
# Replace ',' in values of 'qpprox cost of two people':

df['approx_cost(for two people)'] = df['approx_cost(for two people)'].str.replace(',', '', regex = True)

# %%
# Drop null values in 'approx cost of two people'

df.dropna(subset=['approx_cost(for two people)'], inplace = True)

# %%
# Change dtype of 'approx cost for two people':

df['approx_cost(for two people)'] = df['approx_cost(for two people)'].astype(int)

# %%
# Check dtype of 'approx cost for two people' after changing dtype:

df['approx_cost(for two people)'].dtype
# Out:
# dtype('int32')

# %%
(df.isnull().sum()/len(df))*100
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           19.374745
# votes                           0.000000
# phone                           1.701349
# location                        0.000000
# rest_type                       0.397111
# dish_liked                     54.248506
# cuisines                        0.036986
# approx_cost(for two people)     0.000000
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# rate1                           0.000000
# dtype: float64

# %%
# Replace null values of 'cuisine' with its mode:

df['cuisines'] = df['cuisines'].fillna(df['cuisines'].mode().iloc[0])

# Note: .mode() returns a series and not a single value. That is why we need to use iloc[0] to extract the first and the only value in the mode series. Then using 'fillna()' we can replace the null values with this mode.

# %%
df['cuisines'].isnull().sum()
# Out:
# 0

# %%
df.sample(10)
# Out:
#                                                      url  \
# 14456  https://www.zomato.com/bangalore/baskiins-rabb...
# 17772  https://www.zomato.com/bangalore/smoor-indiran...
# 18453  https://www.zomato.com/bangalore/kerala-vibes-...
# 37661  https://www.zomato.com/bangalore/the-bar-thera...
# 26627  https://www.zomato.com/bangalore/bakers-town-b...
# 43155  https://www.zomato.com/cakeszone?context=eyJzZ...
# 10153  https://www.zomato.com/bangalore/yums-the-word...
# 39811  https://www.zomato.com/bangalore/bib-breakfast...
# 20986  https://www.zomato.com/bangalore/cake-art-jp-n...
# 22300  https://www.zomato.com/bangalore/only-sharjah-...
#
#                                                  address  \
# 14456  Shop 1, Oleshwara Complex, 9th cross, Union Ba...
# 17772  1131, 100 Feet Road, HAL 2nd Stage, Indiranaga...
# 18453  1648/3, Jeevan Bima Nagar Main Road, HAL 3rd S...
# 37661  169, Second Floor, Mahatyagi Laksmidevi Road, ...
# 26627  28, Ground Floor, SG Palaya, Behind Chirst Col...
# 43155  346, 9th Main, 14th Cross, 2nd Stage, CMH Road...
# 10153  117, Mestripalyam Post, KHB Colony, Koramangal...
# 39811  Market Road, 5th Main, Opposite 3rd House, Yes...
# 20986  1982, East End D Main Road, 9th Block, JP Naga...
# 22300    15/1, 1st Stage, 8th Cross Road, BTM, Bangalore
#
#                              name online_order book_table    rate  votes  \
# 14456            Baskiin's Rabbin           No         No     NaN      0
# 17772                       Smoor          Yes         No   4.6/5   1689
# 18453                Kerala Vibes           No         No   3.6/5     80
# 37661             The Bar Therapy           No         No     NaN      0
# 26627                 Bakers Town          Yes         No   3.6/5     42
# 43155                    CakeZone           No         No  4.1 /5    683
# 10153             Yum's The Word!          Yes         No     NaN      0
# 39811  BIB - Breakfast in the Box          Yes         No  3.8 /5     39
# 20986                    Cake Art           No         No   2.9/5     27
# 22300                Only Sharjah          Yes         No     NaN      0
#
#                                   phone               location  \
# 14456                    +91 9819053338        Electronic City
# 17772    080 25211901\r\n+91 8861460270            Indiranagar
# 18453  +91 9744557251\r\n+91 7558007456     Jeevan Bhima Nagar
# 37661                    +91 8618569171  Koramangala 1st Block
# 26627                    +91 7411103666                    BTM
# 43155      080 39513573\n+91 9916888854            Indiranagar
# 10153                    +91 8884045629  Koramangala 4th Block
# 39811                    +91 7005889963            Yeshwantpur
# 20986                      080 26586150               JP Nagar
# 22300                    +91 8553137892                    BTM
#
#                   rest_type  \
# 14456           Quick Bites
# 17772  Dessert Parlor, Cafe
# 18453         Casual Dining
# 37661                   Bar
# 26627                  Cafe
# 43155                Bakery
# 10153              Delivery
# 39811           Quick Bites
# 20986   Bakery, Quick Bites
# 22300         Beverage Shop
#
#                                               dish_liked  \
# 14456                                                NaN
# 17772  Hot Chocolate, Chocolate Pastry, Cheesecake, C...
# 18453                                         Roast Beef
# 37661                                                NaN
# 26627  Fries, Pasta, Chicken Burger, Sandwich, Burger...
# 43155  Cup Cake, Chocolate Truffle, Chocolate Cake, C...
# 10153                                                NaN
# 39811                                                NaN
# 20986                                                NaN
# 22300                                                NaN
#
#                              cuisines  approx_cost(for two people)  \
# 14456  Fast Food, Desserts, Beverages                          300
# 17772       Desserts, Cafe, Beverages                          900
# 18453                          Kerala                          500
# 37661            Continental, Chinese                          800
# 26627    Cafe, Continental, Fast Food                          600
# 43155                Bakery, Desserts                          500
# 10153                         Chinese                          200
# 39811              American, Sandwich                          600
# 20986                          Bakery                          400
# 22300                       Beverages                          200
#
#                                             reviews_list  \
# 14456                                                 []
# 17772  [('Rated 3.0', "RATED\n  Nice place with a lot...
# 18453  [('Rated 4.0', 'RATED\n  Good food. The pepper...
# 37661  [('Rated 5.0', 'RATED\n  Small, cute place wit...
# 26627  [('Rated 3.0', 'RATED\n  Situated in a pretty ...
# 43155  [('Rated 4.0', "RATED\n  We ordered pastry and...
# 10153                                                 []
# 39811  [('Rated 5.0', "RATED\n  The food was really n...
# 20986  [('Rated 3.0', 'RATED\n  I had the Cheese cros...
# 22300  [('Rated 5.0', 'RATED\n  Very nice place and v...
#
#                                                menu_item listed_in(type)  \
# 14456                                                 []        Dine-out
# 17772                                                 []        Delivery
# 18453                                                 []        Delivery
# 37661                                                 []   Pubs and bars
# 26627  ['Oreo Shake', 'Non Veg Nuggets [8 pieces]', '...           Cafes
# 43155                                                 []        Desserts
# 10153                                                 []        Delivery
# 39811                                                 []        Delivery
# 20986                                                 []        Desserts
# 22300  ['Black Dates and Nuts Shake', 'Chocolate with...        Delivery
#
#              listed_in(city)     rate1
# 14456        Electronic City  3.700449
# 17772            Indiranagar  4.600000
# 18453            Indiranagar  3.600000
# 37661  Koramangala 7th Block  3.700449
# 26627  Koramangala 4th Block  3.600000
# 43155                MG Road  4.100000
# 10153                    BTM  3.700449
# 39811           Malleshwaram  3.800000
# 20986              Jayanagar  2.900000
# 22300               JP Nagar  3.700449

# %%
# Drop unrequired columns:

df.drop(['url', 'address', 'phone', 'dish_liked', 'reviews_list', 'menu_item'], axis = 1, inplace = True)

# %%
df.drop(['rate'], axis = 1, inplace = True)

# %%
# Find unique values in 'listed_in(city)':

df['listed_in(city)'].unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block',
#        'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
#        'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
#        'Old Airport Road', 'Rajajinagar', 'Residency Road',
#        'Sarjapur Road', 'Whitefield'], dtype=object)

# %%
# Fill null values of 'rest_type' with its mode:

df['rest_type'] = df['rest_type'].fillna(df['rest_type'].mode().iloc[0])

# %%
df = df.rename(columns = {'rate1':'rate'})

# %%
df['rate'].dtype
# Out:
# dtype('float64')

# %%
(df.isnull().sum()/len(df))*100
# Out:
# name                           0.0
# online_order                   0.0
# book_table                     0.0
# votes                          0.0
# location                       0.0
# rest_type                      0.0
# cuisines                       0.0
# approx_cost(for two people)    0.0
# listed_in(type)                0.0
# listed_in(city)                0.0
# rate                           0.0
# dtype: float64

# %%
df['approx_cost(for two people)'].dtype
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51371 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51371 non-null  object
#  1   online_order                 51371 non-null  object
#  2   book_table                   51371 non-null  object
#  3   votes                        51371 non-null  int64
#  4   location                     51371 non-null  object
#  5   rest_type                    51371 non-null  object
#  6   cuisines                     51371 non-null  object
#  7   approx_cost(for two people)  51371 non-null  int32
#  8   listed_in(type)              51371 non-null  object
#  9   listed_in(city)              51371 non-null  object
#  10  rate                         51371 non-null  float64
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 4.5+ MB

# %%
df = df.rename(columns = {'approx_cost(for two people)':'Cost2Plates'})

# %%
## Checking distribution and removing outliers ##

# %%
# Fetching boxplot for 'rate':

sns.boxplot(data = df['rate'])
# Out:
# <AxesSubplot:>

# %%
# Finding outliers of 'rate':
Q1 = df['rate'].quantile(.25)
Q3 = df['rate'].quantile(.75)
IQR = Q3 - Q1
UL = Q3 + 1.5*(IQR)
LL = Q1 - 1.5*(IQR)
print(UL)
print(LL)
# Out:
# 4.5
# 2.9000000000000004

# %%
# Eliminating outliers by calling nympy:

df['rate'] = np.where(df['rate'] > 4.5, 4, np.where(df['rate'] < 3, 3, df['rate']))

# Note: When we set the lower value in 2.9, we could still see outliers, hence we took 3 and this time all outliers got removed.

# %%
# boxplot after removing outliers:

sns.boxplot(data = df['rate'])
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (51371, 11)

# %%
df['rate'].nunique()
# Out:
# 17

# %%
# Finding outliers for votes: 

sns.boxplot(data = df['votes'])
# Out:
# <AxesSubplot:>

# %%
Q1 = df['votes'].quantile(.25)
Q3 = df['votes'].quantile(.75)
IQR = Q3 - Q1
UL = Q3 + 1.5*(IQR)
LL = Q1 - 1.5*(IQR)
print(UL)
print(LL)
# Out:
# 484.5
# -279.5

# %%
# Removing outliers in vote column:

df['votes'] = np.where(df['votes'] < -279.5, -270, np.where(df['votes'] > 484.4, 484, df['votes']))

# %%
# Boxplot after removing outliers:

sns.boxplot(data = df['votes'])
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51371 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             51371 non-null  object
#  1   online_order     51371 non-null  object
#  2   book_table       51371 non-null  object
#  3   votes            51371 non-null  int64
#  4   location         51371 non-null  object
#  5   rest_type        51371 non-null  object
#  6   cuisines         51371 non-null  object
#  7   Cost2Plates      51371 non-null  int32
#  8   listed_in(type)  51371 non-null  object
#  9   listed_in(city)  51371 non-null  object
#  10  rate             51371 non-null  float64
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 6.5+ MB

# %%
df = df.rename(columns = {'Cost2Plates': 'cost2plates'})

# %%
# Checking outlier for 'cost2plates':

sns.boxplot(data = df['cost2plates'])
# Out:
# <AxesSubplot:>

# %%
# IQR for 'cost2plates':

Q1 = df['cost2plates'].quantile(.25)
Q3 = df['cost2plates'].quantile(.75)
IQR = Q3-Q1
UL = Q3 + 1.5*(IQR)
LL = Q1 - 1.5*(IQR)
print(UL)
print(LL)
# Out:
# 1175.0
# -225.0

# %%
# Removing outlier using numpy:

df['cost2plates'] = np.where(df['cost2plates'] < -225, -225, np.where(df['cost2plates'] > 1175, 1175, df['cost2plates']))

# %%
# Boxplot after removing outliers:

sns.boxplot(data = df['cost2plates'])
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (51371, 11)

# %%
df.isnull().sum()
# Out:
# name               0
# online_order       0
# book_table         0
# votes              0
# location           0
# rest_type          0
# cuisines           0
# cost2plates        0
# listed_in(type)    0
# listed_in(city)    0
# rate               0
# dtype: int64

# %%
# Renaming some columns:

df = df.rename(columns = {'listed_in(type)': 'type', 'listed_in(city)': 'city'})

# %%
# Find no. of unique values in 'location':

df['location'].nunique()
# Out:
# 93

# %%
# Drop 'city' column:

df = df.drop(['city'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51371 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          51371 non-null  object
#  1   online_order  51371 non-null  object
#  2   book_table    51371 non-null  object
#  3   votes         51371 non-null  int64
#  4   location      51371 non-null  object
#  5   rest_type     51371 non-null  object
#  6   cuisines      51371 non-null  object
#  7   cost2plates   51371 non-null  int32
#  8   type          51371 non-null  object
#  9   rate          51371 non-null  float64
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 6.1+ MB

# %%
# Find unique values in 'rest_type':

df['rest_type'].value_counts(ascending = False)
# Out:
# Quick Bites                   19252
# Casual Dining                 10275
# Cafe                           3687
# Delivery                       2587
# Dessert Parlor                 2245
#                               ...
# Dessert Parlor, Kiosk             2
# Food Court, Beverage Shop         2
# Dessert Parlor, Food Court        2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: rest_type, Length: 93, dtype: int64

# %%
df['rest_type'].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', 'Dhaba', 'Quick Bites, Sweet Shop',
#        'Microbrewery', 'Food Court, Quick Bites', 'Pub, Bar',
#        'Casual Dining, Pub', 'Lounge, Bar', 'Food Court, Dessert Parlor',
#        'Casual Dining, Sweet Shop', 'Food Court, Casual Dining',
#        'Casual Dining, Microbrewery', 'Sweet Shop, Dessert Parlor',
#        'Bakery, Beverage Shop', 'Lounge, Casual Dining',
#        'Cafe, Food Court', 'Beverage Shop, Cafe', 'Cafe, Dessert Parlor',
#        'Dessert Parlor, Cafe', 'Dessert Parlor, Bakery',
#        'Microbrewery, Pub', 'Bakery, Food Court', 'Club',
#        'Quick Bites, Food Court', 'Bakery, Cafe', 'Bar, Cafe',
#        'Pub, Cafe', 'Casual Dining, Irani Cafee', 'Fine Dining, Lounge',
#        'Bar, Quick Bites', 'Bakery, Kiosk', 'Pub, Microbrewery',
#        'Microbrewery, Lounge', 'Fine Dining, Microbrewery',
#        'Fine Dining, Bar', 'Mess, Quick Bites', 'Dessert Parlor, Kiosk',
#        'Bhojanalya', 'Casual Dining, Quick Bites', 'Pop Up', 'Cafe, Bar',
#        'Casual Dining, Lounge', 'Bakery, Sweet Shop', 'Microbrewery, Bar',
#        'Cafe, Lounge', 'Bar, Pub', 'Lounge, Cafe', 'Club, Casual Dining',
#        'Quick Bites, Mess', 'Quick Bites, Meat Shop',
#        'Quick Bites, Kiosk', 'Lounge, Microbrewery',
#        'Food Court, Beverage Shop', 'Dessert Parlor, Food Court',
#        'Bar, Lounge'], dtype=object)

# %%
# To minimise the no. of unique values in 'rest_type', we will group all rest_type with values lower than 1000:
# (1) We save the count of 'rest_type' in 'rest_types'.

rest_types = df['rest_type'].value_counts(ascending = False)
rest_types
# Out:
# Quick Bites                   19252
# Casual Dining                 10275
# Cafe                           3687
# Delivery                       2587
# Dessert Parlor                 2245
#                               ...
# Dessert Parlor, Kiosk             2
# Food Court, Beverage Shop         2
# Dessert Parlor, Food Court        2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: rest_type, Length: 93, dtype: int64

# %%
# (2) We create another value 'rest_types_lessthan1000' where we save only 'rest_type' < 1000 from 'rest_types'.

rest_types_lessthan1000 = rest_types[rest_types < 1000]
rest_types_lessthan1000
# Out:
# Beverage Shop                 867
# Bar                           686
# Food Court                    619
# Sweet Shop                    468
# Bar, Casual Dining            415
#                              ...
# Dessert Parlor, Kiosk           2
# Food Court, Beverage Shop       2
# Dessert Parlor, Food Court      2
# Quick Bites, Kiosk              1
# Sweet Shop, Dessert Parlor      1
# Name: rest_type, Length: 85, dtype: int64

# %%
# (3) We define a new function 'handle_rest_type' where we assign 'rest_types_lessthan1000' as 'Others'.

def handle_rest_type(value):
    if(value in rest_types_lessthan1000):
        return 'Others'
    else:
        return value
        
df['rest_type'] = df['rest_type'].apply(handle_rest_type)
df['rest_type'].value_counts()
# Out:
# Quick Bites           19252
# Casual Dining         10275
# Others                 9032
# Cafe                   3687
# Delivery               2587
# Dessert Parlor         2245
# Takeaway, Delivery     2016
# Bakery                 1141
# Casual Dining, Bar     1136
# Name: rest_type, dtype: int64

# %%
# We will proceed with same approach with 'location', 'cuisines', and 'type'
# Location below

df['location'].value_counts(ascending = False)
# Out:
# BTM                      5098
# HSR                      2508
# Koramangala 5th Block    2481
# JP Nagar                 2230
# Whitefield               2133
#                          ...
# West Bangalore              6
# Yelahanka                   5
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: location, Length: 93, dtype: int64

# %%
locations = df['location'].value_counts(ascending = False)
locations_under200 = locations[locations<200]

# %%
def handle_location(value):
    if(value in locations_under200):
        return 'Others'
    else:
        return value

df['location'] = df['location'].apply(handle_location)
df['location'].value_counts()
# Out:
# BTM                      5098
# Others                   3425
# HSR                      2508
# Koramangala 5th Block    2481
# JP Nagar                 2230
# Whitefield               2133
# Indiranagar              2038
# Jayanagar                1918
# Marathahalli             1829
# Bannerghatta Road        1617
# Bellandur                1286
# Electronic City          1257
# Koramangala 1st Block    1237
# Brigade Road             1218
# Koramangala 7th Block    1176
# Koramangala 6th Block    1144
# Sarjapur Road            1055
# Ulsoor                   1017
# Koramangala 4th Block    1017
# Banashankari              906
# MG Road                   894
# Kalyan Nagar              850
# Richmond Road             804
# Malleshwaram              724
# Frazer Town               720
# Basavanagudi              684
# Residency Road            674
# Brookefield               656
# Banaswadi                 653
# New BEL Road              647
# Kammanahalli              645
# Rajajinagar               591
# Church Street             569
# Lavelle Road              523
# Shanti Nagar              511
# Shivajinagar              499
# Cunningham Road           491
# Domlur                    482
# Old Airport Road          443
# Ejipura                   434
# Commercial Street         370
# St. Marks Road            352
# Koramangala 8th Block     302
# Vasanth Nagar             293
# Jeevan Bhima Nagar        272
# Wilson Garden             246
# Bommanahalli              236
# Koramangala 3rd Block     216
# Name: location, dtype: int64

# %%
# Cuisines below:

df['cuisines'].value_counts(ascending = False)
# Out:
# North Indian                                             2891
# North Indian, Chinese                                    2377
# South Indian                                             1822
# Biryani                                                   915
# Bakery, Desserts                                          903
#                                                          ...
# Fast Food, Chinese, Burger, Hot dogs, Sandwich              1
# North Indian, Mughlai, Chinese, Seafood, South Indian       1
# Seafood, Continental, European, Mediterranean               1
# Fast Food, Sandwich, Salad, Healthy Food                    1
# North Indian, Chinese, Arabian, Momos                       1
# Name: cuisines, Length: 2715, dtype: int64

# %%
cuisine = df['cuisines'].value_counts(ascending = False)
cuisine_under100 = cuisine[cuisine<100]

# %%
def handle_cuisines(value):
    if(value in cuisine_under100):
        return 'Others'
    else:
        return value

df['cuisines'] = df['cuisines'].apply(handle_cuisines)

# %%
df['cuisines'].value_counts()
# Out:
# Others                                 26318
# North Indian                            2891
# North Indian, Chinese                   2377
# South Indian                            1822
# Biryani                                  915
#                                        ...
# South Indian, Chinese, North Indian      105
# Italian, Pizza                           105
# North Indian, Mughlai, Chinese           104
# South Indian, Fast Food                  104
# North Indian, Chinese, Seafood           102
# Name: cuisines, Length: 70, dtype: int64

# %%
df.dtypes
# Out:
# name             object
# online_order     object
# book_table       object
# votes             int64
# location         object
# rest_type        object
# cuisines         object
# cost2plates       int32
# type             object
# rate            float64
# dtype: object

# %%
df.head()
# Out:
#                     name online_order book_table  votes      location  \
# 0                  Jalsa          Yes        Yes    484  Banashankari
# 1         Spice Elephant          Yes         No    484  Banashankari
# 2        San Churro Cafe          Yes         No    484  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     88  Banashankari
# 4          Grand Village           No         No    166  Basavanagudi
#
#        rest_type                        cuisines  cost2plates    type  rate
# 0  Casual Dining  North Indian, Mughlai, Chinese          800  Buffet   4.1
# 1  Casual Dining                          Others          800  Buffet   4.1
# 2         Others                          Others          800  Buffet   3.8
# 3    Quick Bites      South Indian, North Indian          300  Buffet   3.7
# 4  Casual Dining                          Others          600  Buffet   3.8

# %%
df.describe()
# Out:
#               votes   cost2plates          rate
# count  51371.000000  51371.000000  51371.000000
# mean     131.156781    512.409239      3.703910
# std      171.715257    304.085918      0.355206
# min        0.000000     40.000000      3.000000
# 25%        7.000000    300.000000      3.500000
# 50%       41.000000    400.000000      3.700449
# 75%      198.000000    650.000000      3.900000
# max      484.000000   1175.000000      4.500000

# %%
## Data is cleaned,let's jump to visualisation ##

# %%
# Heatmap of correlation:

a = sns.heatmap(df.corr(), annot = True, vmin = -1, vmax = 1)
print('Highest correlation exits between cost2plates and rate.')
# Out:
# Highest correlation exits between cost2plates and rate.

# %%
# Countplot of 'location'
# By default, sns does not has a 'sort_values' parameter.
# So we will use sort_values sepately in another variable and use that variable in sns.

location_groupby = df.groupby(['location'])['name'].count()
sorted_location = location_groupby.sort_values(ascending=False).index

a = plt.figure(figsize=(5, 10))
sns.countplot(data=df, y='location', order=sorted_location)
print()
print('Highest number of restaurants are available at BTM, followed by HSR, Koramangala 5th Block, JP Nagar, and Whitefield.')
# Out:
# Highest number of restaurants are available at BTM, followed by HSR, Koramangala 5th Block, JP Nagar, and Whitefield.

# %%
# Pie of 'online_order':

a = df['online_order'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', explode = [0.0, 0.1])
print()
print('59.3% of restaurants offer online_order and 40.7% of restaurants does not offer online_order.')
# Out:
# 59.3% of restaurants offer online_order and 40.7% of restaurants does not offer online_order.

# %%
# Barplot of 'cost2plates' and 'location'

sorted_cost2plates = df.groupby(['location'])['cost2plates'].mean().sort_values(ascending = True).index

a = plt.figure(figsize = (15,10))
sns.barplot(data = df, y = 'cost2plates', x = 'location', ci = None, order = sorted_cost2plates)
plt.xticks(rotation = 90);
print()
print('For two people, cheapest place would be Ejipur and the most expensive will be Lavelle Road.')

# Use semi-colon(;) after 'xticks' to avoid arrays
# Out:
# For two people, cheapest place would be Ejipur and the most expensive will be Lavelle Road.

# %%
# Boxplot: rate - types

a = plt.figure(figsize = (15,5))
sns.boxplot(data = df, x = 'type', y = 'rate')
print()
print('People have given higher rates to Drinks & nightlife, followed by Buffet and Pubs and bars while lowest rates to Delivery and Dine-Out.')
# Out:
# Rates tend to be highest for Drinks & nightlife, followed by Buffet and Pubs and bars while lowest for Delivery and Dine-Out.

# %%
# Barplot: Rates by Location

a = sorted_votes = df.groupby(['location'])['rate'].mean().sort_values(ascending = False).head(10).index
sns.barplot(data = df, y = 'location', x = 'rate', ci = None, order = sorted_votes)
print()
print('Highest rates have been given to restaurants at Lavelle Road and lowest to restaurants at Koramangala 7th block, of the top 10 location.')
# Out:
# Highest rates have been given to restaurants at Lavelle Road and lowest to restaurants at Koramangala 7th block, of the top 10 location.

# %%
# Pie: Book Table

a = df['book_table'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', explode = [0.0, 0.1])
print()
print('87.4% of restaurants do not offer book_table and 12.6% of restaurants offer book_table.')
# Out:
# 87.4% of restaurants do not offer book_table and 12.6% of restaurants offer book_table.

# %%
# Boxplot: Online order vs rate

a = sns.boxplot(data = df, y = 'rate', x = 'online_order')
print()
print('People have given higher rates to restaurants that offer online orders.')
# Out:
# People have given higher rates to restaurants that offer online orders.

# %%
# Boxplot: book_table vs rate:

a = sns.boxplot(data = df, y = 'book_table', x = 'rate')
print()
print('People have given guven higher rates to restaurants that offer book_table against the restaurants that does not offer book table.')
# Out:
# People have given guven higher rates to restaurants that offer book_table against the restaurants that does not offer book table.

# %%
# Countplot: Location vs online_order

a = plt.figure(figsize = (5,15))
sns.countplot(data = df, y = 'location', hue = 'online_order')
print()
print('This shows the restaurants that offer and does not offer online orders in different areas.')
# Out:
# This shows the restaurants that offer and does not offer online orders in different areas.

# %%
# Countplot: location vs book_table

a = plt.figure(figsize = (15,5))
sns.countplot(data = df, x = 'location', hue = 'book_table');
plt.xticks(rotation = 90);
print()
print('Number of restaurants in different locations and whether they offer book_table or not.')
# Out:
# Number of restaurants in different locations and whether they offer book_table or not.

# %%
# Pivot Table : Type vs Location

pivot = pd.pivot_table(df, values='name', index='type', columns='location', aggfunc=len, fill_value=0)
pivot = pivot.loc[:, pivot.sum().sort_values(ascending=False).head(10).index]

pivot
# Note: .head() here gives top 10 columns, not top 10 values.
# Out:
# location             BTM  Others   HSR  Koramangala 5th Block  JP Nagar  \
# type
# Buffet                21      56    19                     65        45
# Cafes                 83      78    49                    146        76
# Delivery            3085    1952  1704                   1076      1158
# Desserts             198     175   123                    209       166
# Dine-out            1670    1067   581                    843       727
# Drinks & nightlife    22      57    14                     84        51
# Pubs and bars         19      40    18                     58         7
#
# location            Whitefield  Indiranagar  Jayanagar  Marathahalli  \
# type
# Buffet                      28           38         27            34
# Cafes                       51           97         77            32
# Delivery                  1062         1098       1043           992
# Desserts                   138          140        182           105
# Dine-out                   774          532        577           640
# Drinks & nightlife          47           67         12            23
# Pubs and bars               33           66          0             3
#
# location            Bannerghatta Road
# type
# Buffet                              9
# Cafes                              46
# Delivery                          831
# Desserts                          137
# Dine-out                          583
# Drinks & nightlife                  9
# Pubs and bars                       2

# %%
# Groupby: Names by votes

df.groupby(['name'])['votes'].sum().sort_values(ascending = False).head(10)
# Out:
# name
# Onesta                    40177
# Empire Restaurant         28982
# Smally's Resto Cafe       24640
# Mainland China            21780
# KFC                       21297
# Hammered                  21047
# Burger King               20814
# Truffles                  20812
# Corner House Ice Cream    20348
# Toscano                   19844
# Name: votes, dtype: int64

# %%
# Barplot: Votes by location

a = sorted_location = df.groupby(['location'])['votes'].sum().sort_values(ascending = False).head(10).index
sns.barplot(data = df, y = 'location', x = df['votes'], estimator = sum, ci = None, order = sorted_location)
print()
print('Restaurants at Koramangala 5th Block. Indiranagar, and BTM have received higher votes from people against the restaurants at Koramangala 6th and 7th block among top 10 votes by location.')
# Out:
# Restaurants at Koramangala 5th Block. Indiranagar, and BTM have received higher votes from people against the restaurants at Koramangala 6th and 7th block among top 10 votes by location.

# %%
# Barplot: Cuisines vs votes

a = df.groupby(['cuisines'])['votes'].sum().sort_values(ascending = False).head(10).iloc[1:]
plt.figure(figsize = (10,5))
sns.barplot(x = a.index, y = a.values)
plt.xticks(rotation = 90);
print()
print('North Indian and North India, Chinese have been votes to be best cuisines by people among top 10 cuisines by votes.')

# iloc[1:] removes the first value from barplot. Without iloc[1:], the first value would be 'Others'.
# Out:
# North Indian and North India, Chinese have been votes to be best cuisines by people among top 10 cuisines by votes.

# %%
# Distribution of rate:

a = sns.distplot(df['rate'])
print()
print('Most restaurants receive reviews of 3.7.')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Most restaurants receive reviews of 3.7.

# %%
# Distribution of cost2plates:

a = sns.distplot(df['cost2plates'])
print()
print('The price for two people in most restaurants is around 300.')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The price for two people in most restaurants is around 300.

# %%
# Distribution of votes:

a = sns.distplot(df['votes'])
print()
print('Most restaurants receive between 0 to 100 votes.')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Most restaurants receive between 0 to 100 votes.
